# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool=sns.load_dataset("titanic")
sns.barplot(x="fare", y="class", hue="sex", data=phool)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool=sns.load_dataset("titanic")
sns.barplot(x="fare", y="class", data=phool, linewidth=4, facecolor=(0.4,0.8,0.2,0.4), errcolor="0.5", edgecolor="0")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11624\1218509819.py:4: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '0.5'}` instead.
#
#   sns.barplot(x="fare", y="class", data=phool, linewidth=4, facecolor=(0.4,0.8,0.2,0.4), errcolor="0.5", edgecolor="0")
