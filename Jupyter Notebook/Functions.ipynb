# %%
# body mass index (BMI)
# input weight
# Height
# BMI
# Weight
# Calculate BMI
# print BMI

# %%
height = input("What is your height?:")
# Out:
# What is your height?: 1.7

# %%
height = float(height)

# %%
weight = input("What is your weight?:")
# Out:
# What is your weight?: 70

# %%
weight = float(weight)

# %%
name = input("What is your name?:")
# Out:
# What is your name?: Shehroz

# %%
BMI = weight/height**2
BMI
# Out:
# 0.014285714285714285

# %%
print("My name is", name, "and my BMI is", BMI)
# Out:
# My name is Shehroz and my BMI is 0.014285714285714285
