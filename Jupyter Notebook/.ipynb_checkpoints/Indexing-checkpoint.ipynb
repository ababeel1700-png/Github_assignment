# %%
# make a string
a = "Muhammad Shehroz"
a
# Out:
# 'Muhammad Shehroz'

# %%
a
# Out:
# 'Muhammad Shehroz'

# %%
a[0]
# Out:
# 'M'

# %%
a[2]
# Out:
# 'h'

# %%
a[5]
# Out:
# 'm'

# %% [markdown]
# #length of Index

# %%
len(a)
# Out:
# 16

# %%
a[0:8]
# Out:
# 'Muhammad'

# %% [markdown]
# **Last index is exclusive:**
# In index count will start from zero but last index is exclusive

# %% [markdown]
# String Methods

# %%
food = "Roti"
food
# Out:
# 'Roti'

# %%
len(food)
# Out:
# 4

# %%
food.capitalize()
# Out:
# 'Roti'

# %%
food.lower()
# Out:
# 'roti'

# %%
food.replace("R", "Sh")
# Out:
# 'Shoti'

# %%
name = "Muhammad Shehroz Bhatti"
name
# Out:
# 'Muhammad Shehroz Bhatti'

# %%
name.count("h")
# Out:
# 4

# %% [markdown]
# **Finding an index in string**

# %%
name="Muhammad Shehroz Bhatti"
name
# Out:
# 'Muhammad Shehroz Bhatti'

# %%
name.find("tt")
# Out:
# 20

# %% [markdown]
# **Spliting a string**

# %%
food = "I love home food like roti, salan, salad and pani"

# %%
food.split(",")
# Out:
# ['I love home food like roti', ' salan', ' salad and pani']
