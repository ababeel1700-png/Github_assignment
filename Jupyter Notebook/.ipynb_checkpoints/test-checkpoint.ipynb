# %% [markdown]
# ## How to Use Jupyter Note book
# #Python Learning
# ###Basic Python

# %%
print("This is Shehroz and it is my first code")
print("i am so excited to take this class")
# Out:
# This is Shehroz and it is my first code
# i am so excited to take this class

# %%
print(2+6)
print(5*8)
print(8/7)
print(9-5)
print(8//2)
print(2**5)

print(8/4)
print(8//4)
# Out:
# 8
# 40
# 1.1428571428571428
# 4
# 4
# 32
# 2.0
# 2

# %%
print(" Hello World")
print("Hello World")
print('we are testing single quotes')
print("we are testing double quotes")
print('''we are testing tripple quotes''')
# Out:
#  Hello World
# Hello World
# we are testing single quotes
# we are testing double quotes
# we are testing tripple quotes

# %%
print(" Hello World")
print("How are your") #Ask how is he
# print('we are testing single quotes')
print("we are testing double quotes")
#print('''we are testing tripple quotes''')
# Out:
#  Hello World
# How are your
# we are testing double quotes

# %%
x=5
print(x)

y="you are all learning new things"
print(y)

x = 8
print(x)

#How to check types of Variable
x=5
print(type(x))

y="you are all learning new things"
print(type(y))

#Rules to assign variables

#1. The Varialbe should contain letter, number or underscores
#2. Do not start with numbers
#3. spaces are not allowed
#4. Do not use functional key_words of python
#5. Short & Descriptive
#6. Case Sensitive (Recomended to use lower case)

fruit_basket= "Mangoes", "Oranges"
print(fruit_basket)
del fruit_basket
fruit_basket= "Mangoes, Oranges"
print(fruit_basket)
print(type(fruit_basket))
# Out:
# 5
# you are all learning new things
# 8
# <class 'int'>
# <class 'str'>
# ('Mangoes', 'Oranges')
# Mangoes, Oranges
# <class 'str'>

# %%
# fruit_basket= "Mangoes", "Oranges"
# print(fruit_basket)


#Input Function
# fruit_basket=input("Which is your favourite fruit?")
# print(fruit_basket)

#Input Function of 2nd stage
# name=input("What is your Name?")
# greetings="Aslam o Alaikum!"

# print(greetings, name)

#Another way of stage 2 function
name=input("what is your name?")
print("Asslam o Alaikum", name)
age=input("How old are your?:")
greeting="Hello!"

print(greeting, name, ", you are so young")
# Out:
# what is your name? Shehroz
# Asslam o Alaikum Shehroz
# How old are your?: 28
# Hello! Shehroz , you are so young

# %%
#logical operation are either "true or False" or "yes or no" or "0 or 1"
#equal to               ==
#Not equal to           !=
#les than               <
#greater than           >
#less than equal to     <=
#Greater than           >=

# print(4!=4)
# print(4==4)
# print(4>2)
# print(4<2)
# print(4>=5)
# print(4<=5)


#pplication of logical operators
# hammad_age= 7
# age_at_school=8
# print(hammad_age==age_at_school)

#input Operator and logics
age_at_school=8
hammad_age=input("How Old is Hammad")
hammad_age=int(hammad_age)
print(hammad_age==age_at_school)
# Out:
# How Old is Hammad 28
# False

# %%
# x=10
# y=15.65
# z="Asslam o Alaikum"

# x=x*y
#Implicit type of Conversion

# print(type(x))
# print(type(y))
# print(type(z))
# print(x, "Type of x is:", type(x))

#Explicit type of conversion
# age=input("What is your age?:")
# # age=int(age)
# print(age, type(int(age)))

Name=input("What is your Name?:")
print(Name, type(str(Name)))
# Out:
# What is your Name?: Shehroz
# Shehroz <class 'str'>

# %%
required_age_school= 5
Ali_age= 1


if Ali_age==required_age_school:
  print("Congratulation! Ali Can join the School") 
elif Ali_age>required_age_school:
  print("Hammad can join Higher school")
elif Ali_age<=2:
  print("Mom should take care of this")
else:
  print("Ali Cannot go to School")
# Out:
# Mom should take care of this

# %%
#defining a function

# def print_trix():
#     print("I am learning from Mr. Ammar")
#     print("I am learning from Mr. Ammar")
#     print("I am learning from Mr. Ammar")

# print_trix()

#2

# def print_trix():
#     text="I am learning from Mr. Ammar"
#     print(text)
#     print(text)
#     print(text)
# print_trix()

#3
# def print_trix(text):
#     print(text)
#     print(text)
#     print(text)

# print_trix("Hi, I am learning Python")

#Defining a function with if, Elif else.

# def school_calculator(age):
#     if age==5:
#         print("Ali Can join the school")
#     elif age>5:
#         print("Ali should go to higher school")
#     else:
#         print("Ali is stil babay")

# school_calculator(2)

#defining a function of future

def future_age(age):
    new_age=age+20
    return new_age
    print(mew_age)

future_prdicted_age=future_age(18)
print(future_prdicted_age)
# Out:
# 38

# %%
#while and for loops

# x=0
# while(x<=5):
#     print(x)
#     x=x+1

#for loop

# for x in range(4, 18):
#     print(x)

#Array
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]

for d in days:
    # if (d=="Fri"):break  #break the loop
    if (d=="Fri"): continue #Skip d
    print(d)
# Out:
# Mon
# Tue
# Wed
# Thu
# Sat
# Sun

# %%
#if you want to print the value of pi

# import math
#print("The value of pi is", math.pi)

import statistics

x=[150, 250, 650, 800]

print(statistics.mean(x))
# Out:
# 462.5

# %%
#print(we are learning with Ammar) #Syntax error

# print(25/0) #runtime error
name= "Ali"
print("Hello", name)
# Out:
# Hello Ali

# %% [markdown]
# **#All above we learned also on VS Code**
