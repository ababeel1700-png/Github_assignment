# %% [markdown]
# #Basic Data Structure

# %% [markdown]
# 1. Tuple
#    -ordered collection of elements
#    -enclosed in () round bracels/paranthesis
#    -different kind of elements can be stored
#    -once elements are stored you cannot change

# %%
tup1 = (1, "python", True, 2.5)
tup1
# Out:
# (1, 'python', True, 2.5)

# %%
type(tup1)
# Out:
# tuple

# %% [markdown]
# ###Indexing in Tuple

# %%
tup1[1]
# Out:
# 'python'

# %%
tup1[2]
# Out:
# True

# %%
tup1[0:3]
# Out:
# (1, 'python', True)

# %%
len(tup1)
# Out:
# 4

# %%
tup2 = (2, "Ali", 5.6, False)
tup2
# Out:
# (2, 'Ali', 5.6, False)

# %%
tup1+ tup2
# Out:
# (1, 'python', True, 2.5, 2, 'Ali', 5.6, False)

# %%
tup3 = (52, 54, 84, 54, 98, 85, 15)
tup3
# Out:
# (52, 54, 84, 54, 98, 85, 15)

# %%
min(tup3)
# Out:
# 15

# %%
max(tup3)
# Out:
# 98

# %%
tup3*2
# Out:
# (52, 54, 84, 54, 98, 85, 15, 52, 54, 84, 54, 98, 85, 15)

# %% [markdown]
# ---

# %% [markdown]
# #List
# -Ordered collection of elements
# -enclosed in [] square braces/brackets
# -Mutateable, You can change the values

# %%
list1 = [2, "Ali", False]
list1
# Out:
# [2, 'Ali', False]

# %%
type(list1)
# Out:
# list

# %%
len(list1)
# Out:
# 3

# %%
list1[2]
# Out:
# False

# %%
list2 = [5, 5.8, "Shehroz", False, 85, "Perfume"]
list2
# Out:
# [5, 5.8, 'Shehroz', False, 85, 'Perfume']

# %%
list1 + list2
# Out:
# [2, 'Ali', False, 5, 5.8, 'Shehroz', False, 85, 'Perfume']

# %%
list1*2
# Out:
# [2, 'Ali', False, 2, 'Ali', False]

# %%
list1.reverse()
list1
# Out:
# [False, 'Ali', 2]

# %%
list1.append("Codanics Youtube Channel")
list1
# Out:
# [False, 'Ali', 2, 'Codanics Youtube Channel']

# %%
list1.copy()
list1
# Out:
# []

# %%
list3 = [20, 40, 50, 15, 18, 64, 95, 84]
len(list3)
# Out:
# 8

# %%
list3.sort()
list3
# Out:
# [15, 18, 20, 40, 50, 64, 84, 95]

# %%
list3*4
# Out:
# [15,
#  18,
#  20,
#  40,
#  50,
#  64,
#  84,
#  95,
#  15,
#  18,
#  20,
#  40,
#  50,
#  64,
#  84,
#  95,
#  15,
#  18,
#  20,
#  40,
#  50,
#  64,
#  84,
#  95,
#  15,
#  18,
#  20,
#  40,
#  50,
#  64,
#  84,
#  95]

# %%
lists = list1 + list3
lists
# Out:
# [15, 18, 20, 40, 50, 64, 84, 95]

# %% [markdown]
# # Dictionaries
# -An unoredered collection of elements
# -Key and Value
# -curly braces or brackets{}
# -Muteable

# %%
d1 = {
    "Samosa":20, "Pakora":40,
    "Rita": 24, "Salad":25, 
    "Chicken Roll":50
}
d1
# Out:
# {'Samosa': 20, 'Pakora': 40, 'Rita': 24, 'Salad': 25, 'Chicken Roll': 50}

# %%
type(d1)
# Out:
# dict

# %%
Food = d1.keys()
Food
# Out:
# dict_keys(['Samosa', 'Pakora', 'Rita', 'Salad', 'Chicken Roll'])

# %%
Food1 = d1.values()
Food1
# Out:
# dict_values([20, 40, 24, 25, 50])

# %%
d1["Tikki"]=10
d1
# Out:
# {'Samosa': 20,
#  'Pakora': 40,
#  'Rita': 24,
#  'Salad': 25,
#  'Chicken Roll': 50,
#  'Tikki': 10}

# %%
d1["Pakora"]=25
d1
# Out:
# {'Samosa': 20,
#  'Pakora': 25,
#  'Rita': 24,
#  'Salad': 25,
#  'Chicken Roll': 50,
#  'Tikki': 10}

# %%
d2 ={
    "Dates":150,
    "choclate":100, 
    "noodels":200
}
d2
# Out:
# {'Dates': 150, 'choclate': 100, 'noodels': 200}

# %%
d1.update(d2)

# %%
d1
# Out:
# {'Samosa': 20,
#  'Pakora': 25,
#  'Rita': 24,
#  'Salad': 25,
#  'Chicken Roll': 50,
#  'Tikki': 10,
#  'Dates': 150,
#  'choclate': 100,
#  'noodels': 200}

# %% [markdown]
# # Sets
# 1. unordered and unindexed
# 2. Curly brace are used{}
# 3. no duplicate allowed

# %%
s1 = {5, 2.5, "Ammar", "Ali", "Codanics", "Lahore"}
s1
# Out:
# {2.5, 5, 'Ali', 'Ammar', 'Codanics', 'Lahore'}

# %%
s1.add("Ahmed")

# %%
s1
# Out:
# {2.5, 5, 'Ahmed', 'Ali', 'Ammar', 'Codanics', 'Lahore'}
