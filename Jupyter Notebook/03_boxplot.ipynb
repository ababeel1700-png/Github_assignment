# %%
import seaborn as sns
seaborn.set(style="whitegrid")
kashti=seaborn.load_dataset("titanic")
seaborn.boxplot(x="class", y="fare", data=kashti)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn as sns

seaborn.set(style="whitegrid")
tip=seaborn.load_dataset("tips")
tip
seaborn.boxplot(x="day", y="tip", data=tip, saturation=1)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pf
import numpy as np

tip=seaborn.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x=tip['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x="sex", y="total_bill", data=tip)
plt.show()

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x="smoker", y="total_bill", data=tip)
plt.show()

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x="tip", y="day", data=tip)
plt.show()

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x="tip", y="day", hue="smoker", data=tip)
plt.show()

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x="tip", y="day", hue="smoker", palette="Set2", data=tip)
plt.show()

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x="tip", y="day", hue="smoker", data=tip, palette="Set2", dodge=True)
plt.show()

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x="tip", y="day", hue="smoker", data=tip, palette="Set2", dodge=False)
plt.show()

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x="tip", y="day", data=tip,saturation=1, orient="h")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

seaborn.boxplot(x="tip", y="day", data=tip, color= "#409c19")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

#individual color bars
colors=["red", "blue", "green", "yellow"]

seaborn.boxplot(x="tip", y="day", data=tip, palette=colors)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1528\974382084.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   seaborn.boxplot(x="tip", y="day", data=tip, palette=colors)
# <Axes: xlabel='tip', ylabel='day'>

# %%
#importing the required module
import seaborn as sns

#use to set style of background of plot
seaborn.set(style="whitegrid")

#Loading data_set
tip=sns.load_dataset("tips")

#individual color bars manually
colors=["red", "blue", "green", "yellow"]

seaborn.boxplot(x="tip", y="day", data=tip)
plt.show()
